
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36',
    'x-autolist-session-guid': 'bb91a84f-e291-4b36-89a9-a901123116d6',
    'x-requested-with': 'XMLHttpRequest',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San Francisco, CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'total_results_count': 514,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=37.7749295&location=San+Francisco%2C+CA&longitude=-122.4194155&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1655514800,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJXCAE2XHF051959',
#    'vdp_url': '/tesla-model+x#vin=5YJXCAE2XHF051959',
#    'clickoff_url': 'https://www.shift.com/car/c1141634?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 245257464,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
response.json().keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %%
response.json()['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1655514800,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJXCAE2XHF051959',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE2XHF051959',
#   'clickoff_url': 'https://www.shift.com/car/c1141634?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 245257464,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OJIU00Qu--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2017,
#   'make': 'Tesla',
#   'model': 'Model X',
#   'model_id': 2101,
#   'display_color': '',
#   'price': '$71,950',
#   'price_unformatted': 71950,
# ...

# %%
len(response.json()['search_results'])
# Out:
# 20

# %%
response.json()['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1655514800,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/5YJXCAE2XHF051959',
#  'vdp_url': '/tesla-model+x#vin=5YJXCAE2XHF051959',
#  'clickoff_url': 'https://www.shift.com/car/c1141634?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 245257464,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OJIU00Qu--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2022/06/23/02/56/2017_tesla_model_x-pic-556834372418005368-1024x768.jpeg',
#  'lat': 37.6397,
#  'lon': -122.416,
#  'year': 2017,
#  'make': 'Tesla',
#  'model': 'Model X',
#  'model_id': 2101,
#  'display_color': '',
#  'price': '$71,950',
#  'price_unformatted': 71950,
# ...

# %%
result_json = response.json()

# %%
#model
result_json['search_results'][0]['model']
# Out:
# 'Model X'

# %%
# mileage
result_json['search_results'][0]['mileage']
# Out:
# '41,257 Miles'

# %%
# year
result_json['search_results'][0]['year']
# Out:
# 2017

# %%
result_json['search_results'][0]['dealer_name']
# Out:
# 'Shift SF - Test Drives Delivered To You'

# %%
result_json['search_results'][0]['price']
# Out:
# '$71,950'

# %%
result_item = result_json['search_results']

# %%
len(result_json['search_results'])
# Out:
# 20

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []
for i in result_item:
    model.append(i['model'])
    mileage.append(i['mileage'])
    year.append(i['year'])
    dealer_name.append(i['dealer_name'])
    price.append(i['price'])

# %%
model, mileage, year, dealer_name, price
# Out:
# (['Model X',
#   'Model 3',
#   'Model 3',
#   'Model 3',
#   'Model 3',
#   'Model 3',
#   'Model S',
#   'Model S',
#   'Model 3',
#   'Model 3',
#   'Model Y',
#   'Model X',
#   'Model 3',
#   'Model 3',
#   'Model S',
#   'Model 3',
#   'Model 3',
#   'Model X',
#   'Model 3',
#   'Model 3'],
#  ['41,257 Miles',
#   '13,286 Miles',
#   '54,274 Miles',
#   '24,394 Miles',
#   '53,078 Miles',
#   '3,698 Miles',
#   '62,259 Miles',
#   '43,718 Miles',
#   '10,982 Miles',
#   '52,425 Miles',
#   '14,270 Miles',
#   '45,729 Miles',
#   '19,371 Miles',
#   '36,870 Miles',
#   '47,921 Miles',
#   '20,241 Miles',
#   '31,476 Miles',
#   '36,467 Miles',
#   '14,155 Miles',
#   '19,692 Miles'],
#  [2017,
#   2019,
#   2019,
#   2019,
#   2018,
#   2021,
#   2018,
#   2018,
#   2019,
#   2019,
#   2021,
#   2018,
#   2019,
#   2019,
#   2018,
#   2018,
#   2018,
#   2018,
#   2019,
#   2018],
#  ['Shift SF - Test Drives Delivered To You',
#   'Shift SF - Test Drives Delivered To You',
# ...

# %%
tesla_df = pd.DataFrame({'Model':model, 'Mileage': mileage,'Dealer Name':dealer_name,
                        'Year':year,'Price':price})

# %%
tesla_df
# Out:
#       Model       Mileage                               Dealer Name  Year  \
# 0   Model X  41,257 Miles   Shift SF - Test Drives Delivered To You  2017
# 1   Model 3  13,286 Miles   Shift SF - Test Drives Delivered To You  2019
# 2   Model 3  54,274 Miles   Shift SF - Test Drives Delivered To You  2019
# 3   Model 3  24,394 Miles   Shift SF - Test Drives Delivered To You  2019
# 4   Model 3  53,078 Miles   Shift SF - Test Drives Delivered To You  2018
# 5   Model 3   3,698 Miles   Shift SF - Test Drives Delivered To You  2021
# 6   Model S  62,259 Miles   Shift SF - Test Drives Delivered To You  2018
# 7   Model S  43,718 Miles                               Manly Honda  2018
# 8   Model 3  10,982 Miles   Shift SF - Test Drives Delivered To You  2019
# 9   Model 3  52,425 Miles   Shift SF - Test Drives Delivered To You  2019
# 10  Model Y  14,270 Miles  Lithia Chrysler Jeep Dodge Of Santa Rosa  2021
# 11  Model X  45,729 Miles                        Volvo Of Palo Alto  2018
# ...

# %%
tesla_df.to_excel('tesla_single_page.xlsx',index = False)

# %% [markdown]
# ## extraction data from multiple pages

# %%
import requests

headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEwMi4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=c9714e49-5d3f-4914-b871-30f10705c428.1656163360664; _gid=GA1.2.894139053.1656163361; _pbjs_userid_consent_data=3524755945110770; _sp_ses.8ca5=*; _fbp=fb.1.1656163361926.1988022957; __gads=ID=82ed8ae2552d9e37:T=1656163362:S=ALNI_MZNrN0CKUDy7sj0f6bgJCRSg1S7Tw; __gpi=UID=000006f6ed225591:T=1656163362:RT=1656163362:S=ALNI_MZ_EQclTCylWBFeOP5DBYuOzO3zYg; _lr_retry_request=true; _lr_env_src_ats=false; pbjs-unifiedid=%7B%22TDID%22%3A%221892dec8-ae67-4dcf-84fb-b423f99b2a51%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222022-05-25T13%3A22%3A43%22%7D; panoramaId_expiry=1656768163202; _cc_id=7a4a7c60b9efdf7da810ccee700ec389; panoramaId=8a0d42726295bcb38053c45e37374945a702cb13ad6f9af0d31757ffee1d7b57; _ga_KKZ1EQJKEV=GS1.1.1656163361.1.1.1656163434.0; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.2.506330545.1656163361; sp-nuid=3385e740-f36d-4f87-a8d8-4862f72ee2ed; _gcl_au=1.1.451794567.1656163437; cto_bundle=zHEDJV9mb1pFTUdKcEdxaFhvQVNJSWhWYlh1ejB5N2dobUR3eUlmeDZHaWVYQ1h2czJ1RWolMkJMUE5TcUFBQ3JvMWlqMG9JJTJCNmY1ZU1mbjkwQzF1UzZ3QSUyRlR1U0ZJNnpGd2hOQWJiQiUyRjVrOWFyQjY3ODRDbWVJbzlSeEY4Z2ZhaW16aGZsVUgwdzZ5Q3p0ZDN6bURZTXMzT1VBQSUzRCUzRA; cto_bundle=zHEDJV9mb1pFTUdKcEdxaFhvQVNJSWhWYlh1ejB5N2dobUR3eUlmeDZHaWVYQ1h2czJ1RWolMkJMUE5TcUFBQ3JvMWlqMG9JJTJCNmY1ZU1mbjkwQzF1UzZ3QSUyRlR1U0ZJNnpGd2hOQWJiQiUyRjVrOWFyQjY3ODRDbWVJbzlSeEY4Z2ZhaW16aGZsVUgwdzZ5Q3p0ZDN6bURZTXMzT1VBQSUzRCUzRA; _pubcid=%7B%22id%22%3A%2201G6DGETVD4BVCC44E54Y1Z2KT%22%2C%22ts%22%3A1656163437229%7D; cto_bidid=a2zxvV9GMmk2STk5TU9HV0VLTWJvZzNoa1lLa2RLbCUyRkpWcGpONEk3blNtUGlMWU5QMTJiJTJCTThsMjAlMkJpYVQwRlhNWVFvUG5leHpmZ2YlMkY4ZEtsenhwRU9PN1Z0SUxXdVFJWmEzemMzTXhiR2lqR3VjJTNE; cto_bundle=DZ6DvV9mb1pFTUdKcEdxaFhvQVNJSWhWYlhoM1BwSDhNWHlRJTJGeUZrS0N0VTRYMXNmUURQU3AlMkJtRXQzWTVpYUE0OU1kSmZoOHhNbWxIT2d4bWRmT1IlMkJUQVp6eUNQUk45ejcxM3JQNiUyRmt3ZDljMTZjdXVZRk94QjIlMkJGNlNPTjE3OCUyRndLRmpFVzZmelZ4cXcwYSUyQm4xcFlPNDc5USUzRCUzRA; _gat=1; _sp_id.8ca5=c04d4b7b-a6f1-4813-af37-4a9017361334.1656163361.1.1656163560.1656163361.3f893ace-4ac9-4155-8aa0-199e1b149024',
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36',
    'x-autolist-session-guid': 'bb91a84f-e291-4b36-89a9-a901123116d6',
    'x-requested-with': 'XMLHttpRequest',
}
for i in range(1,6):
    
    params = (
        ('make', 'Tesla'),
        ('location', 'San Francisco, CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )

    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    # json object
    result_json = response.json()
    
    # json items (20 item per page)
    result_item = response.json()['search_results']

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []
for i in result_item:
    model.append(i['model'])
    mileage.append(i['mileage'])
    year.append(i['year'])
    dealer_name.append(i['dealer_name'])
    price.append(i['price'])

# %%
model
# Out:
# ['Model Y',
#  'Model 3',
#  'Model 3',
#  'Model X',
#  'Model S',
#  'Model 3',
#  'Model 3',
#  'Model S',
#  'Model S',
#  'Model Y',
#  'Model S',
#  'Model X',
#  'Model 3',
#  'Model S',
#  'Model 3',
#  'Model 3',
#  'Model X',
#  'Model 3',
#  'Model Y',
#  'Model S']
